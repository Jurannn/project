# %%
import numpy as np
import pandas as pd
from datetime import datetime
import datetime
import matplotlib.pyplot as plt
import folium

# %%
#한글 폰트 사용
from matplotlib import font_manager,rc
import matplotlib
import matplotlib.pyplot as plt

#폰트 경로
font_path = "C:/Windows/Fonts/H2GTRM.TTF"

#폰트 이름 얻어오기
font_name = font_manager.FontProperties(fname=font_path).get_name()

#font 설정
matplotlib.rc('font',family=font_name)

# %%
occur = pd.read_csv(r"C:\Users\USER\Desktop\데사페\전체_발생건수.csv", encoding='cp949')

# %%
occur.head()
# Out:
#    시도별(1)  성별 및 연령별(1)  성별 및 연령별(2)      2012  2012.1      2013  2013.1  \
# 0  시도별(1)  성별 및 연령별(1)  성별 및 연령별(2)  발생건수 (건)  분율 (%)  발생건수 (건)  분율 (%)
# 1      전국           전체           소계     27823   100.0     29356   100.0
# 2      전국           성별           남자     17851    64.2     18992    64.7
# 3      전국           성별           여자      9930    35.7     10336    35.2
# 4      전국           성별           미상        42     0.2        28     0.1
#
#        2014  2014.1      2015  2015.1      2016  2016.1      2017  2017.1  \
# 0  발생건수 (건)  분율 (%)  발생건수 (건)  분율 (%)  발생건수 (건)  분율 (%)  발생건수 (건)  분율 (%)
# 1     30309   100.0     30771   100.0     29832   100.0     29262   100.0
# 2     19271    63.6     19752    64.2     19122    64.1     18969    64.8
# 3     11015    36.3     11006    35.8     10692    35.8     10288    35.2
# 4        23     0.1        13     0.0        18     0.1         -       -
#
#        2018  2018.1      2019  2019.1
# 0  발생건수 (건)  분율 (%)  발생건수 (건)  분율 (%)
# 1     30539   100.0     30782   100.0
# 2     19557    64.0     19873    64.6
# 3     10977    35.9     10906    35.4
# 4         -       -         -       -

# %%
seoul = occur[occur['시도별(1)'] == '서울']
seoul
# Out:
#    시도별(1) 성별 및 연령별(1) 성별 및 연령별(2)  2012 2012.1  2013 2013.1  2014 2014.1  \
# 15     서울          전체          소계  4179   15.0  4604   15.7  4879   16.1
# 16     서울          성별          남자  2682   64.2  2967   64.4  3047   62.5
# 17     서울          성별          여자  1497   35.8  1634   35.5  1827   37.4
# 18     서울          성별          미상     -      -     -      -     -      -
# 19     서울          나이        0~9세    53    1.3    63    1.4    56    1.1
# 20     서울          나이      10~19세    41    1.0    58    1.3    56    1.1
# 21     서울          나이      20~29세   125    3.0   139    3.0   119    2.4
# 22     서울          나이      30~39세   235    5.6   253    5.5   245    5.0
# 23     서울          나이      40~49세   372    8.9   397    8.6   390    8.0
# 24     서울          나이      50~59세   732   17.5   784   17.0   765   15.7
# 25     서울          나이      60~69세   701   16.8   764   16.6   802   16.4
# 26     서울          나이      70~79세   990   23.7  1077   23.4  1177   24.1
# 27     서울          나이      80세 이상   930   22.3  1065   23.1  1265   25.9
# 28     서울          나이          미상     -      -     -      -     -      -
#
#     2015 2015.1  2016 2016.1  2017 2017.1  2018 2018.1  2019 2019.1
# 15  4804   15.6  4569   15.3  4573   15.6  4717   15.4  4424   14.4
# 16  3067   63.8  2902   63.5  3003   65.7  3036   64.4  2886   65.2
# 17  1735   36.1  1666   36.5  1570   34.3  1681   35.6  1538   34.8
# 18     -      -     -      -     -      -     -      -     -      -
# 19    60    1.2    48    1.1    38    0.8    45    1.0    47    1.1
# 20    58    1.2    37    0.8    42    0.9    62    1.3    48    1.1
# 21   139    2.9   141    3.1   132    2.9   114    2.4   139    3.1
# 22   227    4.7   205    4.5   196    4.3   189    4.0   169    3.8
# 23   415    8.6   414    9.1   390    8.5   383    8.1   311    7.0
# 24   723   15.0   701   15.3   704   15.4   669   14.2   625   14.1
# 25   764   15.9   760   16.6   793   17.3   823   17.4   785   17.7
# 26  1208   25.1  1133   24.8  1123   24.6  1149   24.4  1058   23.9
# 27  1210   25.2  1130   24.7  1155   25.3  1281   27.2  1242   28.1
# 28     -      -     -      -     -      -     -      -     -      -

# %%
seoul1 = seoul.iloc[0]
seoul1
# Out:
# 시도별(1)           서울
# 성별 및 연령별(1)      전체
# 성별 및 연령별(2)      소계
# 2012           4179
# 2012.1         15.0
# 2013           4604
# 2013.1         15.7
# 2014           4879
# 2014.1         16.1
# 2015           4804
# 2015.1         15.6
# 2016           4569
# 2016.1         15.3
# 2017           4573
# 2017.1         15.6
# 2018           4717
# 2018.1         15.4
# 2019           4424
# 2019.1         14.4
# Name: 15, dtype: object

# %%
soccur = seoul1.iloc[1::2][1:].to_frame()
soccur
# Out:
#         15
# 2012  4179
# 2013  4604
# 2014  4879
# 2015  4804
# 2016  4569
# 2017  4573
# 2018  4717
# 2019  4424

# %%
soccur = soccur.reset_index()

# %%
temp = soccur.copy()

# %%
date = []
for i in range(len(temp)):
    str_datetime = soccur['index'][i]
    format = '%Y'
    date.append(datetime.datetime.strptime(str_datetime, format))

# %%
temp['date'] = date

# %%
temp[15] = temp[15].astype(int)
temp
# Out:
#   index    15       date
# 0  2012  4179 2012-01-01
# 1  2013  4604 2013-01-01
# 2  2014  4879 2014-01-01
# 3  2015  4804 2015-01-01
# 4  2016  4569 2016-01-01
# 5  2017  4573 2017-01-01
# 6  2018  4717 2018-01-01
# 7  2019  4424 2019-01-01

# %%
temp.plot(x = 'date', y = 15, label = '서울시 연간 심정지환자 발생 수')
plt.legend()
plt.show()

# %%
seoul1.iloc[::2]
# Out:
# 시도별(1)           서울
# 성별 및 연령별(2)      소계
# 2012.1         15.0
# 2013.1         15.7
# 2014.1         16.1
# 2015.1         15.6
# 2016.1         15.3
# 2017.1         15.6
# 2018.1         15.4
# 2019.1         14.4
# Name: 15, dtype: object

# %%
type(seoul.iloc[0])
# Out:
# pandas.core.series.Series

# %%
occur[occur['성별 및 연령별(1)'] == '전체']
# Out:
#     시도별(1) 성별 및 연령별(1) 성별 및 연령별(2)   2019 2019.1
# 1       전국          전체          소계  30782  100.0
# 15      서울          전체          소계   4424   14.4
# 29      부산          전체          소계   1999    6.5
# 43      대구          전체          소계   1294    4.2
# 57      인천          전체          소계   1548    5.0
# 71      광주          전체          소계    647    2.1
# 85      대전          전체          소계    739    2.4
# 99      울산          전체          소계    624    2.0
# 113     세종          전체          소계    105    0.3
# 127     경기          전체          소계   6848   22.2
# 141     강원          전체          소계   1476    4.8
# 155     충북          전체          소계   1350    4.4
# 169     충남          전체          소계   1738    5.6
# 183     전북          전체          소계   1381    4.5
# 197     전남          전체          소계   1658    5.4
# 211     경북          전체          소계   2157    7.0
# 225     경남          전체          소계   2167    7.0
# 239     제주          전체          소계    627    2.0

# %% [markdown]
# # 전체

# %%
aed = pd.read_csv(r"C:\Users\USER\Desktop\데사페\AED동대문구.csv", encoding='utf-8')

# %%
ddm_map = folium.Map(location=[37.5744,127.0400], zoom_start=14)

# %%
aed_loc = aed.loc[:,('위도', '경도')]

# %%
for i in range(len(aed_loc)):
    #folium.Marker([aed_loc.iloc[i][0], aed_loc.iloc[i][1]], popup=aed_loc.index[i]).add_to(ddm_map)
    folium.Circle([aed_loc.iloc[i][0], aed_loc.iloc[i][1]], radius = 50, popup=aed_loc.index[i], color = 'red', fill = True).add_to(ddm_map)
    #folium.Circle([aed_loc.iloc[i][0], aed_loc.iloc[i][1]], radius = 100, popup=aed_loc.index[i], color = 'blue', fill = True).add_to(ddm_map)
    folium.Circle([aed_loc.iloc[i][0], aed_loc.iloc[i][1]], radius = 200, popup=aed_loc.index[i], color = 'blue', fill = True).add_to(ddm_map)
    #folium.Circle([aed_loc.iloc[i][0], aed_loc.iloc[i][1]], radius = 1000, popup=aed_loc.index[i], color = 'black', fill = False).add_to(ddm_map)


ddm_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aabc9083f3aed5606a5dde4a3e2d2e62 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aabc9083f3aed5606a5dde4a3e2d2e62&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aabc9083f3aed5606a5dde4a3e2d2e62 = L.map(
#                 &quot;map_aabc9083f3aed5606a5dde4a3e2d2e62&quot;,
#                 {
#                     center: [37.5744, 127.04],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3745f7b65f0cf84d17a24a0407400607 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_aabc9083f3aed5606a5dde4a3e2d2e62);
#
#
#             var circle_2d9c17dd88fd60cc49ec19515b771a18 = L.circle(
#                 [37.5852216, 127.0697283],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_aabc9083f3aed5606a5dde4a3e2d2e62);
#
#
#         var popup_47946c93ec6108288c19b2f8e2ad8459 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2bc135c8f537d21cc5026ffdf1a85b0c = $(`&lt;div id=&quot;html_2bc135c8f537d21cc5026ffdf1a85b0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0&lt;/div&gt;`)[0];
#                 popup_47946c93ec6108288c19b2f8e2ad8459.setContent(html_2bc135c8f537d21cc5026ffdf1a85b0c);
#
#
#
#         circle_2d9c17dd88fd60cc49ec19515b771a18.bindPopup(popup_47946c93ec6108288c19b2f8e2ad8459)
#         ;
#
#
#
#
#             var circle_0d384fe2aa4509a40afdad92347bbc4b = L.circle(
#                 [37.5852216, 127.0697283],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 200, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_aabc9083f3aed5606a5dde4a3e2d2e62);
#
#
#         var popup_a567c7459ad291cbfd1a1c5119d97a5c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_509c65215e1be03b06216c2a0ad04600 = $(`&lt;div id=&quot;html_509c65215e1be03b06216c2a0ad04600&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0&lt;/div&gt;`)[0];
#                 popup_a567c7459ad291cbfd1a1c5119d97a5c.setContent(html_509c65215e1be03b06216c2a0ad04600);
#
#
#
#         circle_0d384fe2aa4509a40afdad92347bbc4b.bindPopup(popup_a567c7459ad291cbfd1a1c5119d97a5c)
#         ;
#
#
#
#
#             var circle_09d5d4d045474e56aefae7c139b5d7b3 = L.circle(
#                 [37.57738655, 127.0379219],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_aabc9083f3aed5606a5dde4a3e2d2e62);
#
#
#         var popup_1887d6a5ed6a4b46890fbe0c5d91f51f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3ee4cdfc150f394b67bca0afe5a441a5 = $(`&lt;div id=&quot;html_3ee4cdfc150f394b67bca0afe5a441a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1&lt;/div&gt;`)[0];
#                 popup_1887d6a5ed6a4b46890fbe0c5d91f51f.setContent(html_3ee4cdfc150f394b67bca0afe5a441a5);
#
#
#
#         circle_09d5d4d045474e56aefae7c139b5d7b3.bindPopup(popup_1887d6a5ed6a4b46890fbe0c5d91f51f)
#         ;
#
#
#
#
#             var circle_81e743d9c89082df52a07fd2e1ef7b34 = L.circle(
#                 [37.57738655, 127.0379219],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &q

# %% [markdown]
# # 구급차 제외

# %%
aed_am = pd.read_csv(r"C:\Users\USER\Desktop\데사페\AED동대문구_구급차제외.csv", encoding='utf-8')

# %%
aed_am_loc = aed_am.loc[:,('위도', '경도')]
aed_am_loc.head()
# Out:
#           위도          경도
# 0  37.585222  127.069728
# 1  37.578443  127.062735
# 2  37.567587  127.056497
# 3  37.577655  127.055183
# 4  37.567790  127.058457

# %%
ddm_am_map = folium.Map(location=[37.5744,127.0400], zoom_start=14)

# %%
for i in range(len(aed_am_loc)):
    #folium.Marker([aed_am_loc.iloc[i][0], aed_am_loc.iloc[i][1]], popup=aed_am_loc.index[i]).add_to(ddm_am_map)
    folium.Circle([aed_am_loc.iloc[i][0], aed_am_loc.iloc[i][1]], radius = 50, popup=aed_am_loc.index[i], color = 'red', fill = True).add_to(ddm_am_map)
    #folium.Circle([aed_am_loc.iloc[i][0], aed_am_loc.iloc[i][1]], radius = 100, popup=aed_am_loc.index[i], color = 'blue', fill = True).add_to(ddm_map)
    folium.Circle([aed_am_loc.iloc[i][0], aed_am_loc.iloc[i][1]], radius = 200, popup=aed_am_loc.index[i], color = 'blue', fill = True).add_to(ddm_am_map)
    #folium.Circle([aed_am_loc.iloc[i][0], aed_am_loc.iloc[i][1]], radius = 1000, popup=aed_am_loc.index[i], color = 'black', fill = False).add_to(ddm_map)

ddm_am_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_479f45dc8f0c93aaba68be3ffe3897f7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_479f45dc8f0c93aaba68be3ffe3897f7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_479f45dc8f0c93aaba68be3ffe3897f7 = L.map(
#                 &quot;map_479f45dc8f0c93aaba68be3ffe3897f7&quot;,
#                 {
#                     center: [37.5744, 127.04],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9c18561953b2f5e6e848305bb766db5f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_479f45dc8f0c93aaba68be3ffe3897f7);
#
#
#             var circle_f0ae5f6cd1c4338da6bbeacf9a6ba8f2 = L.circle(
#                 [37.5852216, 127.0697283],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_479f45dc8f0c93aaba68be3ffe3897f7);
#
#
#         var popup_20635bd4ca43fe944a9bdf53c9cc476b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0d7dbd29f64c7d539dea7d26db90efcf = $(`&lt;div id=&quot;html_0d7dbd29f64c7d539dea7d26db90efcf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0&lt;/div&gt;`)[0];
#                 popup_20635bd4ca43fe944a9bdf53c9cc476b.setContent(html_0d7dbd29f64c7d539dea7d26db90efcf);
#
#
#
#         circle_f0ae5f6cd1c4338da6bbeacf9a6ba8f2.bindPopup(popup_20635bd4ca43fe944a9bdf53c9cc476b)
#         ;
#
#
#
#
#             var circle_29ddcb92f1e4735a7d835d4676b4e270 = L.circle(
#                 [37.5852216, 127.0697283],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 200, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_479f45dc8f0c93aaba68be3ffe3897f7);
#
#
#         var popup_bafb17de1401d99ee385e3aa5ef8e0b4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7b43d615fe11722068149903ea597bc7 = $(`&lt;div id=&quot;html_7b43d615fe11722068149903ea597bc7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0&lt;/div&gt;`)[0];
#                 popup_bafb17de1401d99ee385e3aa5ef8e0b4.setContent(html_7b43d615fe11722068149903ea597bc7);
#
#
#
#         circle_29ddcb92f1e4735a7d835d4676b4e270.bindPopup(popup_bafb17de1401d99ee385e3aa5ef8e0b4)
#         ;
#
#
#
#
#             var circle_f92511d273dade21145ddf6a5f76a766 = L.circle(
#                 [37.57844311, 127.0627351],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_479f45dc8f0c93aaba68be3ffe3897f7);
#
#
#         var popup_e3db66d82508b44e2569a2144de7efca = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1294ca4762a523669c1fc7fa0bf8489d = $(`&lt;div id=&quot;html_1294ca4762a523669c1fc7fa0bf8489d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1&lt;/div&gt;`)[0];
#                 popup_e3db66d82508b44e2569a2144de7efca.setContent(html_1294ca4762a523669c1fc7fa0bf8489d);
#
#
#
#         circle_f92511d273dade21145ddf6a5f76a766.bindPopup(popup_e3db66d82508b44e2569a2144de7efca)
#         ;
#
#
#
#
#             var circle_6ddc269cbe6fd736c462cf370ce7824c = L.circle(
#                 [37.57844311, 127.0627351],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &q

# %% [markdown]
# # 24시간

# %%
aed_24 = pd.read_csv(r"C:\Users\USER\Desktop\데사페\AED동대문구_24.csv", encoding='utf-8')

# %%
aed_24_loc = aed_24.loc[:,('위도', '경도')]
aed_24_loc.head()
# Out:
#           위도          경도
# 0  37.567790  127.058457
# 1  37.594077  127.065445
# 2  37.582067  127.074159
# 3  37.582123  127.047209
# 4  37.564664  127.056813

# %%
ddm_24_map = folium.Map(location=[37.5744,127.0400], zoom_start=14)

# %%
for i in range(len(aed_24_loc)):
    #folium.Marker([aed_24_loc.iloc[i][0], aed_24_loc.iloc[i][1]], popup=aed_24_loc.index[i]).add_to(ddm_24_map)
    folium.Circle([aed_24_loc.iloc[i][0], aed_24_loc.iloc[i][1]], radius = 50, popup=aed_24_loc.index[i], color = 'red', fill = True).add_to(ddm_24_map)
    #folium.Circle([aed_24_loc.iloc[i][0], aed_24_loc.iloc[i][1]], radius = 100, popup=aed_24_loc.index[i], color = 'blue', fill = True).add_to(ddm_map)
    folium.Circle([aed_24_loc.iloc[i][0], aed_24_loc.iloc[i][1]], radius = 200, popup=aed_24_loc.index[i], color = 'blue', fill = True).add_to(ddm_24_map)
    #folium.Circle([aed_24_loc.iloc[i][0], aed_24_loc.iloc[i][1]], radius = 1000, popup=aed_24_loc.index[i], color = 'black', fill = False).add_to(ddm_map)

ddm_24_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_abba556e19e853cbf82ab56306e96e72 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_abba556e19e853cbf82ab56306e96e72&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_abba556e19e853cbf82ab56306e96e72 = L.map(
#                 &quot;map_abba556e19e853cbf82ab56306e96e72&quot;,
#                 {
#                     center: [37.5744, 127.04],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e5618e49120bcba323469eb7f9cc130a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_abba556e19e853cbf82ab56306e96e72);
#
#
#             var circle_68cb26bd1249920dc061e051a1a5f73c = L.circle(
#                 [37.56779014, 127.0584569],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_abba556e19e853cbf82ab56306e96e72);
#
#
#         var popup_5b6e1214a770a3b8443fde4339002bef = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6d5d3daccef8dfd6c9badfc59c862c57 = $(`&lt;div id=&quot;html_6d5d3daccef8dfd6c9badfc59c862c57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0&lt;/div&gt;`)[0];
#                 popup_5b6e1214a770a3b8443fde4339002bef.setContent(html_6d5d3daccef8dfd6c9badfc59c862c57);
#
#
#
#         circle_68cb26bd1249920dc061e051a1a5f73c.bindPopup(popup_5b6e1214a770a3b8443fde4339002bef)
#         ;
#
#
#
#
#             var circle_f88088cf61c301a7ab004bebf7924f28 = L.circle(
#                 [37.56779014, 127.0584569],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 200, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_abba556e19e853cbf82ab56306e96e72);
#
#
#         var popup_d90bba3c3b0a87dd5d9b7edcd9412a2b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7f5da8af4312f440d58fd20ffb770284 = $(`&lt;div id=&quot;html_7f5da8af4312f440d58fd20ffb770284&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0&lt;/div&gt;`)[0];
#                 popup_d90bba3c3b0a87dd5d9b7edcd9412a2b.setContent(html_7f5da8af4312f440d58fd20ffb770284);
#
#
#
#         circle_f88088cf61c301a7ab004bebf7924f28.bindPopup(popup_d90bba3c3b0a87dd5d9b7edcd9412a2b)
#         ;
#
#
#
#
#             var circle_9e007233555b3d1d233c5eaaca0bd416 = L.circle(
#                 [37.59407657, 127.0654452],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_abba556e19e853cbf82ab56306e96e72);
#
#
#         var popup_294bfa429bf5fc86b075cd8b88296311 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_099002f8b54a23c73dc9ed7a779788ce = $(`&lt;div id=&quot;html_099002f8b54a23c73dc9ed7a779788ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1&lt;/div&gt;`)[0];
#                 popup_294bfa429bf5fc86b075cd8b88296311.setContent(html_099002f8b54a23c73dc9ed7a779788ce);
#
#
#
#         circle_9e007233555b3d1d233c5eaaca0bd416.bindPopup(popup_294bfa429bf5fc86b075cd8b88296311)
#         ;
#
#
#
#
#             var circle_202b18cbf455a4e73ea649988d4a77e2 = L.circle(
#                 [37.59407657, 127.0654452],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0,
